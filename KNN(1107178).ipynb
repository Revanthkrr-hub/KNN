# %%
import numpy as np
import pandas as pd
import csv
import glob
import os
import random
import operator
import math
from os import listdir
from os.path import isfile, join
from random import shuffle
import pandas as pd
import numpy as np

def ED(data1, data2, length):
    distance = 0
    for x in range(length):
        for i in range(x):
            distance += pow((data1[x]- data2[x]), 2)
            return math.sqrt(distance)

def getNeighbors(trainingSet,instanceTest, k):
    distances = []
    length = len(instanceTest)
    for x in range(len(trainingSet)):
        dist = ED(instanceTest, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
def acc_score(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0
def main():
    myPath =r'C:\Users\Revanth\training_validation'
    allFiles = listdir(myPath)
    print("Total Number of Files: " + str(len(allFiles)))
    classificationSet = []
    datas = []
    for fileName in allFiles :  
        with open(join (myPath,fileName)) as file:                      
            datas.append(list(file.read().replace('\n', '')))
            classificationSet.append(int(str(fileName.split('_')[1]))) # appending file name (label) on the 0th position
    for i in range(0,len(datas)):
        datas[i]= list(map(int,datas[i]))

    #dataSet = [list(a) for a in zip(classificationSet, datas)]  
    dataSet = [list(a) for a in zip(datas, classificationSet)]

    def splitdata(dataset,training=[],test=[]):
        shuffle(dataset)
        l = (int(len(dataset)/5))
        z = (int(l*(5-1)))
        train_Set.extend(dataset[:z])
        test_Set.extend(dataset[z:])
    train_Set=[]
    test_Set=[]
    splitdata(dataSet,train_Set,test_Set)
    print("length of training: "+ repr(len(train_Set)))
    print("length of test: "+ repr(len(test_Set)))
    predictions=[]
    k=3
    for x in range(len(test_Set)):
        neighbors = getNeighbors(train_Set, test_Set[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(test_Set[x][-1]))
    #print(len(predictions))
    accuracy = acc_score(test_Set, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')
main()
# Out:
# Total Number of Files: 1934
# length of training: 1544
# length of test: 390
# Accuracy: 100.0%

# %%
import numpy as np
import pandas as pd
import csv
import glob
import os
import random
import operator
import math
from os import listdir
from os.path import isfile, join
from random import shuffle
import pandas as pd
import numpy as np

def ED(data1, data2, length):
    distance = 0
    for x in range(length):
        for i in range(x):
            distance += pow((data1[x]- data2[x]), 2)
            return math.sqrt(distance)

def getNeighbors(trainingSet,instanceTest, k):
    distances = []
    length = len(instanceTest)
    for x in range(len(trainingSet)):
        dist = ED(instanceTest, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
def acc_score(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0
def main():
    myPath =r'C:\Users\Revanth\training_validation'
    allFiles = listdir(myPath)
    print("Total Number of validation Files: " + str(len(allFiles)))
    classificationSet = []
    datas = []
    for fileName in allFiles :  
        with open(join (myPath,fileName)) as file:                      
            datas.append(list(file.read().replace('\n', '')))
            classificationSet.append(int(str(fileName.split('_')[1]))) 
    for i in range(0,len(datas)):
        datas[i]= list(map(int,datas[i]))

    #dataSet = [list(a) for a in zip(classificationSet, datas)]  
    dataSet = [list(a) for a in zip(datas, classificationSet)]

    train_Set=dataSet
    
    new_myPath =r'C:\Users\Revanth\test'
    new_allFiles = listdir(new_myPath)
    print("Total Number of test Files: " + str(len(new_allFiles)))
    new_classificationSet = []
    new_datas = []
    for fileName in new_allFiles :  
        with open(join (new_myPath,fileName)) as file:                      
            new_datas.append(list(file.read().replace('\n', '')))
            new_classificationSet.append(int(str(fileName.split('_')[1])))
    for i in range(0,len(new_datas)):
        new_datas[i]= list(map(int,new_datas[i]))

    #dataSet = [list(a) for a in zip(classificationSet, datas)]  
    new_dataSet = [list(a) for a in zip(new_datas, new_classificationSet)]


    test_Set=new_dataSet
    #print(len(test_Set))
    
    print("length of training: "+ repr(len(train_Set)))
    print("length of test: "+ repr(len(test_Set)))
    predictions=[]
    acc_table=[]
    for k in range(1,12):
        #print(k)
        for x in range(len(test_Set)):
            neighbors = getNeighbors(train_Set,test_Set[x], k)
            result = getResponse(neighbors)
            predictions.append(result)
            #print('> predicted=' + repr(result) + ', actual=' + repr(test_Set[x][-1]))
        #print(len(predictions))
        accuracy = acc_score(test_Set, predictions)
        acc_table.append(accuracy)
        print('k=' + repr(k))
        print('Accuracy: '+ repr(accuracy) + '%')
main()
# Out:
# Total Number of validation Files: 1934
# Total Number of test Files: 946
# length of training: 1934
# length of test: 946
# k=1
# Accuracy: 100.0%
# k=2
# Accuracy: 100.0%
# k=3
# Accuracy: 100.0%
# k=4
# Accuracy: 100.0%
# k=5
# Accuracy: 100.0%
# k=6
# Accuracy: 100.0%
# k=7
# Accuracy: 100.0%
# k=8
# Accuracy: 100.0%
# k=9
# Accuracy: 100.0%
# k=10
# Accuracy: 100.0%
# k=11
# Accuracy: 100.0%
